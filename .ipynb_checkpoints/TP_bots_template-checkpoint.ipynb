# %%
# !pip install -r requirements.txt
# Out:
# Collecting pandas==2.2.3 (from -r requirements.txt (line 1))
#   Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting numpy==2.1.2 (from -r requirements.txt (line 2))
#   Downloading numpy-2.1.2-cp310-cp310-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: requests==2.32.3 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from -r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from -r requirements.txt (line 4)) (2.9.0.post0)
# Collecting scikit-learn==1.5.2 (from -r requirements.txt (line 5))
#   Downloading scikit_learn-1.5.2-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting scipy==1.14.1 (from -r requirements.txt (line 6))
#   Downloading scipy-1.14.1-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting tqdm==4.66.5 (from -r requirements.txt (line 7))
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting urllib3==2.2.3 (from -r requirements.txt (line 8))
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting joblib==1.4.2 (from -r requirements.txt (line 9))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting jupyterlab==4.2.5 (from -r requirements.txt (line 10))
#   Downloading jupyterlab-4.2.5-py3-none-any.whl.metadata (16 kB)
# Collecting matplotlib==3.9.2 (from -r requirements.txt (line 11))
#   Downloading matplotlib-3.9.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting seaborn==0.13.2 (from -r requirements.txt (line 12))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: json5==0.9.25 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from -r requirements.txt (line 13)) (0.9.25)
# Collecting statsmodels==0.14.4 (from -r requirements.txt (line 14))
#   Downloading statsmodels-0.14.4-cp310-cp310-win_amd64.whl.metadata (9.5 kB)
# Collecting types-python-dateutil==2.9.0.20241003 (from -r requirements.txt (line 16))
#   Downloading types_python_dateutil-2.9.0.20241003-py3-none-any.whl.metadata (1.9 kB)
# Collecting pytz>=2020.1 (from pandas==2.2.3->-r requirements.txt (line 1))
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.3->-r requirements.txt (line 1))
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 3)) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from requests==2.32.3->-r requirements.txt (line 3)) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from python-dateutil==2.9.0.post0->-r requirements.txt (line 4)) (1.16.0)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn==1.5.2->-r requirements.txt (line 5))
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from tqdm==4.66.5->-r requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (3.1.5)
# Requirement already satisfied: jupyter-core in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.2.3)
# Requirement already satisfied: packaging in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (24.2)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (75.8.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (6.4.2)
# Requirement already satisfied: traitlets in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 10)) (5.14.3)
# Collecting contourpy>=1.0.1 (from matplotlib==3.9.2->-r requirements.txt (line 11))
#   Downloading contourpy-1.3.1-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib==3.9.2->-r requirements.txt (line 11))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.9.2->-r requirements.txt (line 11))
#   Downloading fonttools-4.56.0-cp310-cp310-win_amd64.whl.metadata (103 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib==3.9.2->-r requirements.txt (line 11))
#   Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib==3.9.2->-r requirements.txt (line 11))
#   Downloading pillow-11.1.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib==3.9.2->-r requirements.txt (line 11))
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting patsy>=0.5.6 (from statsmodels==0.14.4->-r requirements.txt (line 14))
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from async-lru>=1.0.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (4.12.2)
# Requirement already satisfied: anyio in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (4.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (8.30.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (26.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jinja2>=3.0.3->jupyterlab==4.2.5->-r requirements.txt (line 10)) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-core->jupyterlab==4.2.5->-r requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-core->jupyterlab==4.2.5->-r requirements.txt (line 10)) (308)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.16.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 10)) (4.23.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (21.2.0)
# Requirement already satisfied: decorator in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 10)) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 10)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: webencodings in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.8.4)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10))
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10))
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10))
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10))
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10))
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: wcwidth in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.2.5)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.5)
# Requirement already satisfied: executing in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (0.2.2)
# Requirement already satisfied: pycparser in c:\users\aymeline\anaconda3\envs\tp4se\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10)) (2.21)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 10))
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.6 MB 1.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.6 MB 2.6 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.6 MB 2.9 MB/s eta 0:00:04
#    --------- ------------------------------ 2.9/11.6 MB 2.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.6 MB 3.1 MB/s eta 0:00:03
#    --------------- ------------------------ 4.5/11.6 MB 3.3 MB/s eta 0:00:03
#    ------------------ --------------------- 5.5/11.6 MB 3.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.6/11.6 MB 3.6 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.6 MB 3.8 MB/s eta 0:00:02
#    ------------------------------- -------- 9.2/11.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.6 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 4.5 MB/s eta 0:00:00
# Downloading numpy-2.1.2-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.9 MB 10.1 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.9 MB 10.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.8/12.9 MB 9.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.6/12.9 MB 9.4 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.9 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.9 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 9.6 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp310-cp310-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/11.0 MB 10.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/11.0 MB 11.4 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.0 MB 10.8 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.0 MB 10.9 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 9.7 MB/s eta 0:00:00
# Downloading scipy-1.14.1-cp310-cp310-win_amd64.whl (44.8 MB)
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    - -------------------------------------- 1.6/44.8 MB 8.4 MB/s eta 0:00:06
#    --- ------------------------------------ 3.7/44.8 MB 9.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 5.2/44.8 MB 8.6 MB/s eta 0:00:05
#    ------ --------------------------------- 6.8/44.8 MB 8.6 MB/s eta 0:00:05
#    ------- -------------------------------- 8.7/44.8 MB 8.5 MB/s eta 0:00:05
#    --------- ------------------------------ 10.7/44.8 MB 8.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 12.6/44.8 MB 9.0 MB/s eta 0:00:04
#    ------------- -------------------------- 14.7/44.8 MB 9.0 MB/s eta 0:00:04
#    -------------- ------------------------- 16.3/44.8 MB 8.7 MB/s eta 0:00:04
#    --------------- ------------------------ 17.8/44.8 MB 8.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 19.4/44.8 MB 8.6 MB/s eta 0:00:03
#    ------------------ --------------------- 20.7/44.8 MB 8.4 MB/s eta 0:00:03
#    ------------------- -------------------- 21.8/44.8 MB 8.2 MB/s eta 0:00:03
#    -------------------- ------------------- 22.5/44.8 MB 8.0 MB/s eta 0:00:03
#    --------------------- ------------------ 23.6/44.8 MB 7.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.2/44.8 MB 7.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 26.0/44.8 MB 7.4 MB/s eta 0:00:03
#    ------------------------ --------------- 27.0/44.8 MB 7.3 MB/s eta 0:00:03
#    ------------------------- -------------- 28.8/44.8 MB 7.3 MB/s eta 0:00:03
#    -------------------------- ------------- 30.1/44.8 MB 7.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 31.5/44.8 MB 7.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.5/44.8 MB 7.2 MB/s eta 0:00:02
#    ------------------------------ --------- 34.3/44.8 MB 7.3 MB/s eta 0:00:02
#    ------------------------------- -------- 35.7/44.8 MB 7.2 MB/s eta 0:00:02
#    --------------------------------- ------ 37.0/44.8 MB 7.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 38.3/44.8 MB 7.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.6/44.8 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------ --- 40.9/44.8 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------- -- 42.2/44.8 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.8 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  44.6/44.8 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 MB 6.9 MB/s eta 0:00:00
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading jupyterlab-4.2.5-py3-none-any.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.6 MB 5.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.6 MB 7.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.6 MB 5.1 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.6 MB 5.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.6 MB 4.9 MB/s eta 0:00:02
#    ------------------- -------------------- 5.8/11.6 MB 4.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.6/11.6 MB 4.7 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.6 MB 4.4 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.6 MB 4.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.4/11.6 MB 4.1 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.6 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 4.5 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp310-cp310-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/7.8 MB 5.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/7.8 MB 5.6 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/7.8 MB 5.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/7.8 MB 5.5 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.8 MB 5.5 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.8 MB 5.5 MB/s eta 0:00:01
#    ------------------------- -------------- 5.0/7.8 MB 3.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.8/7.8 MB 3.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.8/7.8 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/7.8 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.8 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 2.9 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.4-cp310-cp310-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 3.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.8 MB 4.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/9.8 MB 4.3 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.8 MB 4.4 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.8 MB 4.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.8 MB 4.5 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.8 MB 4.5 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 4.2 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20241003-py3-none-any.whl (9.7 kB)
# Downloading contourpy-1.3.1-cp310-cp310-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp310-cp310-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.2 MB 6.1 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 4.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading pillow-11.1.0-cp310-cp310-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    --------------- ------------------------ 1.0/2.6 MB 5.0 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.6 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 4.5 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Installing collected packages: pytz, webcolors, urllib3, uri-template, tzdata, types-python-dateutil, tqdm, threadpoolctl, pyparsing, pillow, numpy, kiwisolver, jsonpointer, joblib, fqdn, fonttools, cycler, scipy, patsy, pandas, contourpy, arrow, statsmodels, scikit-learn, matplotlib, isoduration, seaborn, jupyterlab
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 4.3.4
#     Uninstalling jupyterlab-4.3.4:
#       Successfully uninstalled jupyterlab-4.3.4
# Successfully installed arrow-1.3.0 contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 fqdn-1.5.1 isoduration-20.11.0 joblib-1.4.2 jsonpointer-3.0.0 jupyterlab-4.2.5 kiwisolver-1.4.8 matplotlib-3.9.2 numpy-2.1.2 pandas-2.2.3 patsy-1.0.1 pillow-11.1.0 pyparsing-3.2.1 pytz-2025.1 scikit-learn-1.5.2 scipy-1.14.1 seaborn-0.13.2 statsmodels-0.14.4 threadpoolctl-3.5.0 tqdm-4.66.5 types-python-dateutil-2.9.0.20241003 tzdata-2025.1 uri-template-1.3.0 urllib3-2.2.3 webcolors-24.11.1

# %%
import requests
import joblib
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from pandas import option_context
from tqdm import tqdm
from statsmodels.stats.inter_rater import aggregate_raters
from sklearn.metrics import cohen_kappa_score
from scipy.stats import mannwhitneyu,shapiro,ttest_ind

import cliffsDelta as cd
import GenerateActivities as gat
import important_features as imf

# %%
QUERY_ROOT = "https://api.github.com"
TOKEN = '' # write your GitHub API key here
HEADERS={'Authorization':'token '+TOKEN}

# %% [markdown]
# ## Section 3

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### Write an automated Python script to identify all GitHub bot actors in the list of contributors, by querying the GitHub REST API users endpoint and extracting the required information to make this decision.
#
# #### More information: You can search for the "type" key in the obtianed JSON result, If it is "Bot", then it is a bot actor, if it is "User", then it is an account.

# %%
# 1. Read the given <sample>.csv file into a pandas DataFrame (df).
# 2. Make sure there are 2 columns, one column name is "contributor" that has the name of the contributor, 
#    and another column name is "bothunter_type" that you will use later on in this assignment.
# 3. Display the DataFrame.

# YOUR CODE BELOW

df = pd.read_csv("Contributors/sample23.csv")

print(df.columns)

print(df)
# Out:
# Index(['contributor', 'bothunter_type'], dtype='object')
#                       contributor bothunter_type
# 0                    Coderambling          Human
# 1                         Intron7          Human
# 2                      ParsifalXu          Human
# 3                 StefanKarpinski          Human
# 4                      adamltyson          Human
# 5                      anutosh491          Human
# 6                       benrutter          Human
# 7                         cat-bro          Human
# 8                    codecov[bot]            Bot
# 9                codspeed-hq[bot]            Bot
# 10                       commit-0          Human
# 11                      coveralls            Bot
# 12                       datejada          Human
# 13                   editorialbot          Human
# 14                     emmanuelle          Human
# 15                          giovp          Human
# 16            github-actions[bot]            Bot
# 17  github-advanced-security[bot]            Bot
# 18                       hvwaldow          Human
# 19                    imagesc-bot            Bot
# 20                       jennaswa          Human
# 21                      jsspencer          Human
# 22                          kp992          Human
# 23                      lucyleeow          Human
# 24                         maxnoe          Human
# 25                meeseeksmachine            Bot
# 26                       mosc9575          Human
# 27                    nanosoldier          Human
# 28                   netlify[bot]            Bot
# 29                  norlandrhagen          Human
# 30                     pangeo-bot            Bot
# 31                        pdebuyl          Human
# 32                       petscbot            Bot
# 33             pre-commit-ci[bot]            Bot
# 34                        rcurtin          Human
# 35                  renovate[bot]            Bot
# 36                       scottyhq          Human
# 37                         takagi          Human
# 38                      ufechner7          Human
# 39                       yuanx749          Human

# %%
# 1. Store the names of the contributors in a list
# 2. print the list

# YOUR CODE BELOW

contributors = df["contributor"].tolist()

print(contributors)
# Out:
# ['Coderambling', 'Intron7', 'ParsifalXu', 'StefanKarpinski', 'adamltyson', 'anutosh491', 'benrutter', 'cat-bro', 'codecov[bot]', 'codspeed-hq[bot]', 'commit-0', 'coveralls', 'datejada', 'editorialbot', 'emmanuelle', 'giovp', 'github-actions[bot]', 'github-advanced-security[bot]', 'hvwaldow', 'imagesc-bot', 'jennaswa', 'jsspencer', 'kp992', 'lucyleeow', 'maxnoe', 'meeseeksmachine', 'mosc9575', 'nanosoldier', 'netlify[bot]', 'norlandrhagen', 'pangeo-bot', 'pdebuyl', 'petscbot', 'pre-commit-ci[bot]', 'rcurtin', 'renovate[bot]', 'scottyhq', 'takagi', 'ufechner7', 'yuanx749']

# %%
# 1. Using a for loop, iterate over each contributor in the list and query the GitHub Users API.
#    You can use "query = f'{QUERY_ROOT}/users/{contributor}'", where QUERY_ROOT is defined at the beginning of this notebook 
#    and 'contributor' is each individual contributor from the list
# 2. Get the response using 'response = requests.get(query, headers=HEADERS)'.
# 3. convert the response to JSON using 'json_response = response.json()'.
# 4. Iterate over each JSON response and get the value of the 'type' key. If it is "Bot" then the contributor is a bot actor, 
#    if "User" then the contributor is an account. You should boolean values to indicate if the contributor is a bot actor (True) or User/Organisation (False)
# 5. Save these results in list of dictionary of the form [{'contributor': <contributor name>, 'app': <boolean value>}, {...}, {...}, {...}].
#    Lets call this list as "app_dict"
# 6. Finally convert this list of dictionary to DataFrame by writing 'pd.DataFrame.from_dict(app_dict)'
# 7. Display the DataFrame. This should have two columns - contributor and app


# YOUR CODE BELOW

app_dict = []

for contributor in contributors:
    query = f"{QUERY_ROOT}/users/{contributor}"
    
    response = requests.get(query, headers=HEADERS)
    json_response = response.json()
        
    is_bot = json_response.get("type") == "Bot"
        
    app_dict.append({"contributor": contributor, "app": is_bot})

app_df = pd.DataFrame.from_dict(app_dict)

print(app_df)
# Out:
#                       contributor    app
# 0                    Coderambling  False
# 1                         Intron7  False
# 2                      ParsifalXu  False
# 3                 StefanKarpinski  False
# 4                      adamltyson  False
# 5                      anutosh491  False
# 6                       benrutter  False
# 7                         cat-bro  False
# 8                    codecov[bot]   True
# 9                codspeed-hq[bot]   True
# 10                       commit-0  False
# 11                      coveralls  False
# 12                       datejada  False
# 13                   editorialbot  False
# 14                     emmanuelle  False
# 15                          giovp  False
# 16            github-actions[bot]   True
# 17  github-advanced-security[bot]   True
# 18                       hvwaldow  False
# 19                    imagesc-bot  False
# 20                       jennaswa  False
# 21                      jsspencer  False
# 22                          kp992  False
# 23                      lucyleeow  False
# 24                         maxnoe  False
# 25                meeseeksmachine  False
# 26                       mosc9575  False
# 27                    nanosoldier  False
# 28                   netlify[bot]   True
# 29                  norlandrhagen  False
# 30                     pangeo-bot  False
# 31                        pdebuyl  False
# 32                       petscbot  False
# 33             pre-commit-ci[bot]   True
# 34                        rcurtin  False
# 35                  renovate[bot]   True
# 36                       scottyhq  False
# 37                         takagi  False
# 38                      ufechner7  False
# 39                       yuanx749  False

# %% [markdown]
# ### Question 2
#
# #### Add a new 'actor' column in the CSV file to store this information. You can write True if it is a bot actor and False if it is not.
#
# #### Report on the total number of GitHub bot actors, and User accounts present in the list of accounts of your dataset.

# %%
# Merge the app DataFrame to df by writing 'pd.merge(df, <app df>, on='contributor'). This is similar to SQL join on primary key 'contributor'.
# The resultant df should have 3 columns - contributor, bothunter_type and user_type.

# YOUR CODE BELOW

merged_data = pd.merge(df, app_df, on='contributor')
merged_data = merged_data.rename(columns={'app': 'user_type'})
print(merged_data)

num_bots = sum(merged_data["user_type"])
num_users = len(merged_data) - num_bots

print(f"Total GitHub Bot Actors: {num_bots}")
print(f"Total GitHub User Accounts: {num_users}")
# Out:
#                       contributor bothunter_type  user_type
# 0                    Coderambling          Human      False
# 1                         Intron7          Human      False
# 2                      ParsifalXu          Human      False
# 3                 StefanKarpinski          Human      False
# 4                      adamltyson          Human      False
# 5                      anutosh491          Human      False
# 6                       benrutter          Human      False
# 7                         cat-bro          Human      False
# 8                    codecov[bot]            Bot       True
# 9                codspeed-hq[bot]            Bot       True
# 10                       commit-0          Human      False
# 11                      coveralls            Bot      False
# 12                       datejada          Human      False
# 13                   editorialbot          Human      False
# 14                     emmanuelle          Human      False
# 15                          giovp          Human      False
# 16            github-actions[bot]            Bot       True
# 17  github-advanced-security[bot]            Bot       True
# 18                       hvwaldow          Human      False
# 19                    imagesc-bot            Bot      False
# 20                       jennaswa          Human      False
# 21                      jsspencer          Human      False
# 22                          kp992          Human      False
# 23                      lucyleeow          Human      False
# 24                         maxnoe          Human      False
# 25                meeseeksmachine            Bot      False
# 26                       mosc9575          Human      False
# 27                    nanosoldier          Human      False
# 28                   netlify[bot]            Bot       True
# 29                  norlandrhagen          Human      False
# 30                     pangeo-bot            Bot      False
# 31                        pdebuyl          Human      False
# 32                       petscbot            Bot      False
# 33             pre-commit-ci[bot]            Bot       True
# 34                        rcurtin          Human      False
# 35                  renovate[bot]            Bot       True
# 36                       scottyhq          Human      False
# 37                         takagi          Human      False
# 38                      ufechner7          Human      False
# 39                       yuanx749          Human      False
# Total GitHub Bot Actors: 7
# Total GitHub User Accounts: 33

# %% [markdown]
# ### Question 3
#
# #### For each bot actor, write their purpose, the task that they automate by looking at their GitHub profile, homepage, information on the GitHub Marketplace, or other documentation that you can find online.

# %% [markdown]
# ## Section 4

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### Write an automated script to use BIMBAS (Bot Identification Model Based on Activity Sequences) to obtain a prediction of the GitHub contributor type (Bot or Human) for the contributors present in your dataset.
#
# #### Folow the steps given in each cell to use BIMBAS and obtain predictions.

# %% [markdown]
# ### Read all the events and select the events performed by the contributors present in the given set

# %%
# 1. Read the csv file of events (all_events.csv) provided along with this notebook
# 2. Convert created_at column to datetime format 
#    One possible way is to use lambda function: "events.assign(created_at=lambda d: pd.to_datetime(d.created_at, unit='ms'))"
# 3. Get the contributors provided to you in a list or use the contributors list that you created in Section 3 Question 1. 
#    e.g., ['contributor1', 'contributor2', 'contributor3',...]
# 4. Select the events performed by these contributors alone. Do not consider all the events. You should consider only the events
#    performed by the contributors provided to you. Hint: you can use the df.query function
# 5. Display the considered events.

# YOUR CODE BELOW


events_df = pd.read_csv("all_events.csv")

events_df = events_df.assign(created_at=lambda d: pd.to_datetime(d.created_at, unit="ms"))

filtered_events = events_df.query("login in @contributors")

print(filtered_events)
# Out:
#         Unnamed: 0     event_id          event_type                login  \
# 3                3  39747379822   IssueCommentEvent         codecov[bot]
# 6                6  39747396929  CommitCommentEvent  github-actions[bot]
# 15              15  39747413489  CommitCommentEvent  github-actions[bot]
# 16              16  39747416135           PushEvent  github-actions[bot]
# 21              21  39747427332         CreateEvent  github-actions[bot]
# ...            ...          ...                 ...                  ...
# 358397      358397  42415358855   IssueCommentEvent     codspeed-hq[bot]
# 358398      358398  42415372311   IssueCommentEvent         codecov[bot]
# 358401      358401  42415474205           PushEvent  github-actions[bot]
# 358403      358403  42415512378           PushEvent  github-actions[bot]
# 358428      358428  42415647911           PushEvent   pre-commit-ci[bot]
#
#                                           repository          created_at  \
# 3                                      napari/napari 2024-07-01 00:00:10
# 6                     QuantEcon/lecture-python-intro 2024-07-01 00:01:47
# 15                    QuantEcon/lecture-python-intro 2024-07-01 00:03:24
# 16                                    napari/npe2api 2024-07-01 00:03:40
# 21                                  SciML/PubChem.jl 2024-07-01 00:04:44
# ...                                              ...                 ...
# 358397                                   conda/conda 2024-09-30 23:27:57
# 358398                            pybamm-team/PyBaMM 2024-09-30 23:28:49
# 358401  Bioconductor/gha-build-jupyter-release-amd64 2024-09-30 23:34:53
# 358403                                napari/npe2api 2024-09-30 23:37:12
# 358428                        bokeh/bokeh_sampledata 2024-09-30 23:45:44
#
#          action  PR_number   state           PR_node_id  ...  \
# 3       created     7043.0    open  PR_kwDOCJ0aI85z_6lX  ...
# 6           NaN        NaN     NaN                  NaN  ...
# 15          NaN        NaN     NaN                  NaN  ...
# 16          NaN        NaN     NaN                  NaN  ...
# 21          NaN        NaN     NaN                  NaN  ...
# ...         ...        ...     ...                  ...  ...
# 358397  created    14285.0    open  PR_kwDOAF8kJs59LhsL  ...
# 358398  created     4477.0  closed  PR_kwDOCUVVSc59LeQ9  ...
# 358401      NaN        NaN     NaN                  NaN  ...
# 358403      NaN        NaN     NaN                  NaN  ...
# 358428      NaN        NaN     NaN                  NaN  ...
#
#             comment_node_id merged  \
# 3       IC_kwDOCJ0aI86DDzXh    NaN
# 6       CC_kwDOIy5DFs4IkKwX    NaN
# 15      CC_kwDOIy5DFs4IkKw0    NaN
# 16                      NaN    NaN
# 21                      NaN    NaN
# ...                     ...    ...
# 358397  IC_kwDOAF8kJs6OHzZU    NaN
# 358398  IC_kwDOCUVVSc6OH0Z2    NaN
# 358401                  NaN    NaN
# 358403                  NaN    NaN
# 358428                  NaN    NaN
#
#                                                       ref ref_type  \
# 3                                                     NaN      NaN
# 6                                                     NaN      NaN
# 15                                                    NaN      NaN
# 16                                                    NaN      NaN
# 21      compathelper/new_version/2024-07-01-00-04-42-9...   branch
# ...                                                   ...      ...
# 358397                                                NaN      NaN
# 358398                                                NaN      NaN
# 358401                                                NaN      NaN
# 358403                                                NaN      NaN
# 358428                                                NaN      NaN
#
#         issue_number issue_node_id issue_closed_at tag_name release_node_id  \
# 3                NaN           NaN             NaN      NaN             NaN
# 6                NaN           NaN             NaN      NaN             NaN
# 15               NaN           NaN             NaN      NaN             NaN
# 16               NaN           NaN             NaN      NaN             NaN
# 21               NaN           NaN             NaN      NaN             NaN
# ...              ...           ...             ...      ...             ...
# 358397           NaN           NaN             NaN      NaN             NaN
# 358398           NaN           NaN             NaN      NaN             NaN
# 358401           NaN           NaN             NaN      NaN             NaN
# 358403           NaN           NaN             NaN      NaN             NaN
# 358428           NaN           NaN             NaN      NaN             NaN
#
#                  org
# 3             napari
# 6          QuantEcon
# 15         QuantEcon
# 16            napari
# 21             SciML
# ...              ...
# 358397         conda
# 358398   pybamm-team
# 358401  Bioconductor
# 358403        napari
# 358428         bokeh
#
# [111421 rows x 25 columns]

# %% [markdown]
# ### Execute BIMBAS to obtain the predictions

# %%
# Do not modify this cell
# Use the following function the code below to obtain your predictions

def execute_bimbas(contributors_list, selected_events):
    '''
    args: contributors_list (list) - list of contributors in the dataset provided to you
          selected_events (DataFrame) - DataFrame of events performed by the considered contributors
    return: bimbas_prediction (DataFrame) - DataFrame of preditions along with the confidence in prediction for each contributor
    '''
    result=pd.DataFrame()
    temp_list = []
    bimbas = joblib.load('bimbas.joblib')
    date_limit = pd.to_datetime(selected_events.created_at.max()) + pd.DateOffset(-90)
    
    for contributor in tqdm(contributors_list):
        # c = contributors[contributor]
        activities = gat.activity_identification(selected_events.query('login==@contributor and created_at>=@date_limit'))
        activity_features = (
                            imf.extract_features(activities)
                            .set_index([[contributor]])
                            )
        # features = pd.concat([features,activity_features])
        with warnings.catch_warnings():
            warnings.simplefilter("ignore", category=UserWarning)
            probability = bimbas.predict_proba(activity_features)[0][1]
        if(probability <= 0.5):
            contributor_type = 'Human'
        else:
            contributor_type = 'Bot'
        confidence = (abs(probability - 0.5)*2).round(3)
    
        pred = activity_features.set_index([[contributor]]).assign(
            prediction=contributor_type,
            confidence = confidence,
            )
        temp_list.extend([{'contributor':contributor,'bimbas_type':contributor_type,'confidence':confidence}])
    
    bimbas_prediction = pd.DataFrame.from_dict(temp_list)

    return(bimbas_prediction)

# %%
# Write your code here to call execute_bimbas function. 
# Pass the contributors list and the filtered events DataFrame as argument to "execute_bimbas" function
# Prediction returned by BIMBAS will have "contributor", "bimbas_type" and "confidence"
# Note: Print the prediction provided by BIMBAS - else this cell will not be graded.

# YOUR CODE BELOW

prediction = execute_bimbas(contributors, filtered_events)
print(prediction)
# Out:
# 100%|██████████| 40/40 [00:15<00:00,  2.64it/s]
#                       contributor bimbas_type  confidence
# 0                    Coderambling       Human       0.864
# 1                         Intron7       Human       0.915
# 2                      ParsifalXu       Human       0.869
# 3                 StefanKarpinski       Human       0.885
# 4                      adamltyson         Bot       0.774
# 5                      anutosh491       Human       0.938
# 6                       benrutter       Human       0.893
# 7                         cat-bro       Human       0.781
# 8                    codecov[bot]         Bot       0.938
# 9                codspeed-hq[bot]         Bot       0.916
# 10                       commit-0         Bot       0.857
# 11                      coveralls         Bot       0.910
# 12                       datejada       Human       0.738
# 13                   editorialbot         Bot       0.471
# 14                     emmanuelle         Bot       0.938
# 15                          giovp       Human       0.836
# 16            github-actions[bot]         Bot       0.145
# 17  github-advanced-security[bot]         Bot       0.703
# 18                       hvwaldow         Bot       0.731
# 19                    imagesc-bot       Human       0.145
# 20                       jennaswa       Human       0.893
# 21                      jsspencer       Human       0.779
# 22                          kp992       Human       0.878
# 23                      lucyleeow       Human       0.849
# 24                         maxnoe       Human       0.909
# 25                meeseeksmachine         Bot       0.791
# 26                       mosc9575       Human       0.949
# 27                    nanosoldier         Bot       0.896
# 28                   netlify[bot]         Bot       0.925
# 29                  norlandrhagen       Human       0.953
# 30                     pangeo-bot         Bot       0.372
# 31                        pdebuyl         Bot       0.886
# 32                       petscbot         Bot       0.791
# 33             pre-commit-ci[bot]         Bot       0.936
# 34                        rcurtin       Human       0.803
# 35                  renovate[bot]         Bot       0.166
# 36                       scottyhq       Human       0.949
# 37                         takagi       Human       0.857
# 38                      ufechner7       Human       0.782
# 39                       yuanx749       Human       0.903

# %% [markdown]
# ### Create a column in your predictions DataFrame to have predictions provided by BIMBAS.
# ### Now your DataFrame should have the following columns - contributor, bothunter_type, app, bimbas_type, confidence

# %% [markdown]
# ### Merging bothunter and bimbas predictions

# %%
# Merge the predictions provided by BIMBAS to the resultant dataset of Section 3. This final DataFrame should have the following columns - 
# contributor, bothunter_type, user_type, bimbas_type, and confidence.

predictions_df = pd.merge(merged_data, prediction, on='contributor')
predictions_df.head()
# Out:
#        contributor bothunter_type  user_type bimbas_type  confidence
# 0     Coderambling          Human      False       Human       0.864
# 1          Intron7          Human      False       Human       0.915
# 2       ParsifalXu          Human      False       Human       0.869
# 3  StefanKarpinski          Human      False       Human       0.885
# 4       adamltyson          Human      False         Bot       0.774

# %% [markdown]
# ### Question 2
# #### Using Cohen's Kappa compute and report the interrater agreement score between the labels computed by both the bot identification approaches. Mention your interpretation of Cohen's Kappa

# %%
# Hint: use the cohen_kappa_score library
# YOUR CODE BELOW

kappa_score = cohen_kappa_score(predictions_df["bothunter_type"], predictions_df["bimbas_type"])

print(f"Cohen's Kappa Score: {kappa_score:.3f}")
# Out:
# Cohen's Kappa Score: 0.583

# %% [markdown]
# ### Question 3
# #### Determine the final type of each contributor. Whenever user_type column has the value "User" check if both bimbas_type and bothunter_type give the same prediction, then consider it as your final prediction in "acc_type" column.
# #### For the contributors that have different predictions, i.e. bimbas_type is not same as bothunter_type, then make a manual verification and consider that as the type for that contributor. Add an extra column to the DataFrame ﬁle called 'manual' that has the label determined by you.
# #### For manual verification you can make use the GitHub UI and the GitHub API https://api.github.com/users/username
#
# #### Whenever user_type column has the value "Bot", directly write your final acc_type as "Bot Actor"
#
# #### More information:
# For each contributor, you can look at their activities in GitHub UI, look at their latest events using GitHub Events API - https://api.github.com/users/<contributor>/events, to make a decision on their type.
#
# In addition, you can also write a very small reason why do you think they are bot or human (e.g., same activity at regular interval so Bot, files committed and code modified looks like Human, comments look like Human, comment look like Bot, test report looks automated so Bot, and so on....). This will be useful to answer your next question.

# %%
# Write the code for your manual decision here
# example : 
# manual_list_dict = [{'contributor': '<contributor name>', 'manual': '<your prediction>'}, {....}, {....}, {....}]
# pd.DataFrame.from_dict(manual_list_dict)

# YOUR CODE BELOW

diff_contributors = predictions_df.query("bothunter_type != bimbas_type")["contributor"]
print(diff_contributors)

manual_list_dict = [
    {'contributor' : 'adamltyson', 'manual': 'Human'},
    {'contributor' : 'commit-0', 'manual': 'Bot'},
    {'contributor' : 'editorialbot', 'manual': 'Bot'},
    {'contributor' : 'emmanuelle', 'manual': 'Human'},
    {'contributor' : 'hvwaldow', 'manual': 'Human'},
    {'contributor' : 'imagesc-bot', 'manual': 'Human'},
    {'contributor' : 'nanosoldier', 'manual': 'Bot'},
    {'contributor' : 'pdebuyl', 'manual': 'Human'}
]

manual_df = pd.DataFrame.from_dict(manual_list_dict)
# Out:
# 4       adamltyson
# 10        commit-0
# 13    editorialbot
# 14      emmanuelle
# 18        hvwaldow
# 19     imagesc-bot
# 27     nanosoldier
# 31         pdebuyl
# Name: contributor, dtype: object

# %%
# Write your code below here to determine the final type of contributor.
# add column named 'acc_type' and write your final decision in it. Final decision is majority of three types - bimbas_type, bothunter_type, manual.

final_type_df = predictions_df.merge(manual_df, on="contributor", how="left")
def determine_final_type(row):
    if row["user_type"] == "Bot":
        return "Bot Actor"
    elif row["bothunter_type"] == row["bimbas_type"]:
        return row["bothunter_type"]
    else:
        return row["manual"]  # Utiliser la décision manuelle en cas de désaccord

final_type_df["acc_type"] = final_type_df.apply(determine_final_type, axis=1)

print(final_type_df)
# Out:
#                       contributor bothunter_type  user_type bimbas_type  \
# 0                    Coderambling          Human      False       Human
# 1                         Intron7          Human      False       Human
# 2                      ParsifalXu          Human      False       Human
# 3                 StefanKarpinski          Human      False       Human
# 4                      adamltyson          Human      False         Bot
# 5                      anutosh491          Human      False       Human
# 6                       benrutter          Human      False       Human
# 7                         cat-bro          Human      False       Human
# 8                    codecov[bot]            Bot       True         Bot
# 9                codspeed-hq[bot]            Bot       True         Bot
# 10                       commit-0          Human      False         Bot
# 11                      coveralls            Bot      False         Bot
# 12                       datejada          Human      False       Human
# 13                   editorialbot          Human      False         Bot
# 14                     emmanuelle          Human      False         Bot
# 15                          giovp          Human      False       Human
# 16            github-actions[bot]            Bot       True         Bot
# 17  github-advanced-security[bot]            Bot       True         Bot
# 18                       hvwaldow          Human      False         Bot
# 19                    imagesc-bot            Bot      False       Human
# 20                       jennaswa          Human      False       Human
# 21                      jsspencer          Human      False       Human
# 22                          kp992          Human      False       Human
# 23                      lucyleeow          Human      False       Human
# 24                         maxnoe          Human      False       Human
# 25                meeseeksmachine            Bot      False         Bot
# 26                       mosc9575          Human      False       Human
# 27                    nanosoldier          Human      False         Bot
# 28                   netlify[bot]            Bot       True         Bot
# 29                  norlandrhagen          Human      False       Human
# 30                     pangeo-bot            Bot      False         Bot
# 31                        pdebuyl          Human      False         Bot
# 32                       petscbot            Bot      False         Bot
# 33             pre-commit-ci[bot]            Bot       True         Bot
# 34                        rcurtin          Human      False       Human
# 35                  renovate[bot]            Bot       True         Bot
# 36                       scottyhq          Human      False       Human
# 37                         takagi          Human      False       Human
# 38                      ufechner7          Human      False       Human
# 39                       yuanx749          Human      False       Human
#
#     confidence acc_type manual
# 0        0.864    Human    NaN
# 1        0.915    Human    NaN
# 2        0.869    Human    NaN
# 3        0.885    Human    NaN
# 4        0.774    Human  Human
# 5        0.938    Human    NaN
# 6        0.893    Human    NaN
# 7        0.781    Human    NaN
# 8        0.938      Bot    NaN
# 9        0.916      Bot    NaN
# 10       0.857      Bot    Bot
# 11       0.910      Bot    NaN
# 12       0.738    Human    NaN
# 13       0.471      Bot    Bot
# 14       0.938    Human  Human
# 15       0.836    Human    NaN
# 16       0.145      Bot    NaN
# 17       0.703      Bot    NaN
# 18       0.731    Human  Human
# 19       0.145    Human  Human
# 20       0.893    Human    NaN
# 21       0.779    Human    NaN
# 22       0.878    Human    NaN
# 23       0.849    Human    NaN
# 24       0.909    Human    NaN
# 25       0.791      Bot    NaN
# 26       0.949    Human    NaN
# 27       0.896      Bot    Bot
# 28       0.925      Bot    NaN
# 29       0.953    Human    NaN
# 30       0.372      Bot    NaN
# 31       0.886    Human  Human
# 32       0.791      Bot    NaN
# 33       0.936      Bot    NaN
# 34       0.803    Human    NaN
# 35       0.166      Bot    NaN
# 36       0.949    Human    NaN
# 37       0.857    Human    NaN
# 38       0.782    Human    NaN
# 39       0.903    Human    NaN

# %% [markdown]
# ### Question 4
# #### Study and report the purpose of these identified bots and humans in the repository assigned to you.
# #### For example, the purpose can be based on but not limited to -
# ##### 1) the type of activities that they are performing (releasing a version on every Sunday, updating the documentation),
# ##### 2) type of comments they are posting (reviewing code, test summary report),
# ##### 3) when are they triggered (when a new PR is created, when someone in the project ask the bot to merge the code) and so on.
# #### Note:
# ##### The purpose can be other than what is provided in examples above.

# %% [markdown]
# ## Section 5

# %% [markdown]
# ### Question 1
# #### Use the filtered events file that has the events performed by the contributors provided to you
# #### Group each event into the following four categories
#
# Issues: IssueCommentEvent, IssuesEvent
# Pull Requests: PullRequestEvent, PullRequestReviewCommentEvent
# Commits: CommitCommentEvent, PushEvent
# Repository: CreateEvent, DeleteEvent, ForkEvent, GollumEvent, MemberEvent, PublicEvent, ReleaseEvent, SponsorshipEvent, WatchEvent
#
# #### Hint:
# 1. Add a column called event_group that mentions which event group does that event belong to. Each event (row) should correspond to an event group.
# 2. Then perform groupby on ['login','event_group'],
# 3. use .agg (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.agg.html) to count the number of events performed by each contributor in each group,
# 4. use pivot with the required arguments (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pivot.html). An example is given [here](#pivot_example) in question 2(b), and
# 5. Reset index and rename axis with None
# 7. Finally merge it with your 'acc_type' field from the DataFrame you created in Section4, drop contributor, and fillna with 0
# 8. The final DataFrame should have the following columns - login, PR, commit, issue, repo, acc_type
#
# The final DataFrame should be looking like the following
# ![](event_group.png)

# %%
# In the resultant DataFrame - each row should corespond to a contributor, and the columns should have all the event groups  
# and the type of the contributor (that you decided in the previous DataFrame) and the values should be the number 
# of events of that event event group the contriubutor has performed.

issue_group = ['IssueCommentEvent', 'IssuesEvent']
pr_group = ['PullRequestEvent', 'PullRequestReviewCommentEvent']
commit_group = ['CommitCommentEvent', 'PushEvent']
repo_group = ['CreateEvent', 'DeleteEvent', 'ForkEvent', 'GollumEvent', 'MemberEvent', 'PublicEvent', 'ReleaseEvent', 'SponsorshipEvent', 'WatchEvent']

# %%
# YOUR CODE BELOW
# Définir une fonction pour attribuer chaque événement à un groupe
def classify_event(event):
    if event in issue_group:
        return "issue"
    elif event in pr_group:
        return "PR"
    elif event in commit_group:
        return "commit"
    elif event in repo_group:
        return "repository"

# Appliquer cette fonction sur la colonne 'type' du DataFrame
filtered_events["event_group"] = filtered_events["event_type"].apply(classify_event)
print(filtered_events)
# Out:
#         Unnamed: 0     event_id          event_type                login  \
# 3                3  39747379822   IssueCommentEvent         codecov[bot]
# 6                6  39747396929  CommitCommentEvent  github-actions[bot]
# 15              15  39747413489  CommitCommentEvent  github-actions[bot]
# 16              16  39747416135           PushEvent  github-actions[bot]
# 21              21  39747427332         CreateEvent  github-actions[bot]
# ...            ...          ...                 ...                  ...
# 358397      358397  42415358855   IssueCommentEvent     codspeed-hq[bot]
# 358398      358398  42415372311   IssueCommentEvent         codecov[bot]
# 358401      358401  42415474205           PushEvent  github-actions[bot]
# 358403      358403  42415512378           PushEvent  github-actions[bot]
# 358428      358428  42415647911           PushEvent   pre-commit-ci[bot]
#
#                                           repository          created_at  \
# 3                                      napari/napari 2024-07-01 00:00:10
# 6                     QuantEcon/lecture-python-intro 2024-07-01 00:01:47
# 15                    QuantEcon/lecture-python-intro 2024-07-01 00:03:24
# 16                                    napari/npe2api 2024-07-01 00:03:40
# 21                                  SciML/PubChem.jl 2024-07-01 00:04:44
# ...                                              ...                 ...
# 358397                                   conda/conda 2024-09-30 23:27:57
# 358398                            pybamm-team/PyBaMM 2024-09-30 23:28:49
# 358401  Bioconductor/gha-build-jupyter-release-amd64 2024-09-30 23:34:53
# 358403                                napari/npe2api 2024-09-30 23:37:12
# 358428                        bokeh/bokeh_sampledata 2024-09-30 23:45:44
#
#          action  PR_number   state           PR_node_id  ... merged  \
# 3       created     7043.0    open  PR_kwDOCJ0aI85z_6lX  ...    NaN
# 6           NaN        NaN     NaN                  NaN  ...    NaN
# 15          NaN        NaN     NaN                  NaN  ...    NaN
# 16          NaN        NaN     NaN                  NaN  ...    NaN
# 21          NaN        NaN     NaN                  NaN  ...    NaN
# ...         ...        ...     ...                  ...  ...    ...
# 358397  created    14285.0    open  PR_kwDOAF8kJs59LhsL  ...    NaN
# 358398  created     4477.0  closed  PR_kwDOCUVVSc59LeQ9  ...    NaN
# 358401      NaN        NaN     NaN                  NaN  ...    NaN
# 358403      NaN        NaN     NaN                  NaN  ...    NaN
# 358428      NaN        NaN     NaN                  NaN  ...    NaN
#
#                                                       ref  ref_type  \
# 3                                                     NaN       NaN
# 6                                                     NaN       NaN
# 15                                                    NaN       NaN
# 16                                                    NaN       NaN
# 21      compathelper/new_version/2024-07-01-00-04-42-9...    branch
# ...                                                   ...       ...
# 358397                                                NaN       NaN
# 358398                                                NaN       NaN
# 358401                                                NaN       NaN
# 358403                                                NaN       NaN
# 358428                                                NaN       NaN
#
#        issue_number  issue_node_id issue_closed_at tag_name release_node_id  \
# 3               NaN            NaN             NaN      NaN             NaN
# 6               NaN            NaN             NaN      NaN             NaN
# 15              NaN            NaN             NaN      NaN             NaN
# 16              NaN            NaN             NaN      NaN             NaN
# 21              NaN            NaN             NaN      NaN             NaN
# ...             ...            ...             ...      ...             ...
# 358397          NaN            NaN             NaN      NaN             NaN
# 358398          NaN            NaN             NaN      NaN             NaN
# 358401          NaN            NaN             NaN      NaN             NaN
# 358403          NaN            NaN             NaN      NaN             NaN
# 358428          NaN            NaN             NaN      NaN             NaN
#
#                  org  event_group
# 3             napari        issue
# 6          QuantEcon       commit
# 15         QuantEcon       commit
# 16            napari       commit
# 21             SciML   repository
# ...              ...          ...
# 358397         conda        issue
# 358398   pybamm-team        issue
# 358401  Bioconductor       commit
# 358403        napari       commit
# 358428         bokeh       commit
#
# [111421 rows x 26 columns]
# C:\Users\Aymeline\AppData\Local\Temp\ipykernel_67416\4004583583.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_events["event_group"] = filtered_events["event_type"].apply(classify_event)

# %%
# YOUR CODE BELOW
event_counts = (
    filtered_events
    .groupby(["login", "event_group"])
    .size()
    .reset_index(name="event_count")
)

event_pivot = event_counts.pivot(index="login", columns="event_group", values="event_count")

event_pivot = event_pivot.fillna(0).reset_index()

final_df = event_pivot.merge(final_type_df[["contributor", "acc_type"]], left_on="login", right_on="contributor", how="left")

final_df = final_df.drop(columns=["contributor"])

final_df = final_df.rename(columns={"login": "contributor"})

print(final_df)
# Out:
#                       contributor      PR   commit   issue  repository  \
# 0                    Coderambling    14.0      2.0    48.0         0.0
# 1                         Intron7    79.0    193.0    38.0        73.0
# 2                      ParsifalXu     5.0      0.0     8.0         2.0
# 3                 StefanKarpinski     3.0      1.0    25.0         0.0
# 4                      adamltyson     0.0      0.0    83.0         0.0
# 5                      anutosh491    90.0      7.0    77.0         3.0
# 6                       benrutter     5.0      0.0     9.0         1.0
# 7                         cat-bro    12.0      4.0    15.0         1.0
# 8                    codecov[bot]     0.0      0.0  1683.0         0.0
# 9                codspeed-hq[bot]     0.0      0.0   186.0         0.0
# 10                       commit-0     0.0      0.0     0.0        35.0
# 11                      coveralls     0.0      0.0   268.0         0.0
# 12                       datejada     0.0      0.0     7.0         3.0
# 13                   editorialbot   710.0   2866.0  7111.0      2966.0
# 14                     emmanuelle     0.0     41.0     0.0         0.0
# 15                          giovp    73.0     96.0   158.0        47.0
# 16            github-actions[bot]  1060.0  84814.0  2139.0      1192.0
# 17  github-advanced-security[bot]    32.0      0.0     0.0         0.0
# 18                       hvwaldow     0.0      0.0    10.0         0.0
# 19                    imagesc-bot     0.0      0.0    17.0         0.0
# 20                       jennaswa    21.0     49.0     7.0        14.0
# 21                      jsspencer     3.0      0.0     7.0         1.0
# 22                          kp992     6.0      0.0     6.0         3.0
# 23                      lucyleeow    87.0      5.0   129.0         1.0
# 24                         maxnoe    14.0      0.0    29.0         1.0
# 25                meeseeksmachine   253.0      0.0     0.0         2.0
# 26                       mosc9575    32.0      8.0    31.0         4.0
# 27                    nanosoldier     0.0    107.0   102.0         0.0
# 28                   netlify[bot]     0.0      0.0   343.0         0.0
# 29                  norlandrhagen    16.0     28.0    25.0        11.0
# 30                     pangeo-bot     5.0      7.0     8.0         5.0
# 31                        pdebuyl     0.0      0.0    19.0         0.0
# 32                       petscbot     0.0    230.0     0.0         5.0
# 33             pre-commit-ci[bot]   473.0    628.0     0.0       408.0
# 34                        rcurtin   286.0     44.0    84.0         6.0
# 35                  renovate[bot]   158.0    127.0    12.0       233.0
# 36                       scottyhq    22.0     12.0    18.0        22.0
# 37                         takagi    37.0     23.0    56.0         0.0
# 38                      ufechner7     1.0      0.0    30.0         1.0
# 39                       yuanx749    21.0      0.0    16.0         0.0
#
#    acc_type
# 0     Human
# 1     Human
# 2     Human
# 3     Human
# 4     Human
# 5     Human
# 6     Human
# 7     Human
# 8       Bot
# 9       Bot
# 10      Bot
# 11      Bot
# 12    Human
# 13      Bot
# 14    Human
# 15    Human
# 16      Bot
# 17      Bot
# 18    Human
# 19    Human
# 20    Human
# 21    Human
# 22    Human
# 23    Human
# 24    Human
# 25      Bot
# 26    Human
# 27      Bot
# 28      Bot
# 29    Human
# 30      Bot
# 31    Human
# 32      Bot
# 33      Bot
# 34    Human
# 35      Bot
# 36    Human
# 37    Human
# 38    Human
# 39    Human

# %% [markdown]
# ### Question 2 (a)
#
# #### Compute the median number of events per event group for Bot+Bot actors and Humans and write in DataFrame.
#
# Row should correspond to type (Bot_BotActor and Human), Column should have Event group name and the values should be the median value of Bot_BotActor or Human for that particular event group. An example is given below

# %%
# For example:
medians = [{'event_group': 'event_group1', 'median': 'val1', 'acc_type': 'Bot_app'}, 
           {'event_group': 'event_group1', 'median': 'val2', 'acc_type': 'Human'},
           {'event_group': 'event_group2', 'median': 'val3', 'acc_type': 'Bot_app'},
           {'event_group': 'event_group2', 'median': 'val4', 'acc_type': 'Human'},
           {'event_group': 'event_group3', 'median': 'val5', 'acc_type': 'Bot_app'},
           {'event_group': 'event_group3', 'median': 'val6', 'acc_type': 'Human'},
           {'event_group': 'event_group4', 'median': 'val7', 'acc_type': 'Bot_app'},
           {'event_group': 'event_group5', 'median': 'val8', 'acc_type': 'Human'}]
df_medians = pd.DataFrame.from_dict(medians)
df_medians
# Out:
#     event_group median acc_type
# 0  event_group1   val1  Bot_app
# 1  event_group1   val2    Human
# 2  event_group2   val3  Bot_app
# 3  event_group2   val4    Human
# 4  event_group3   val5  Bot_app
# 5  event_group3   val6    Human
# 6  event_group4   val7  Bot_app
# 7  event_group5   val8    Human

# %%
# YOUR CODE BELOW
median_events = final_df.groupby("acc_type")[["PR", "commit", "issue", "repository"]].median()

# Reformater pour obtenir une colonne avec 'event_group'
median_events = median_events.T.reset_index().melt(id_vars="index", var_name="acc_type", value_name="median_value")

# Renommer correctement la colonne index -> event_group
median_events = median_events.rename(columns={"index": "event_group"})

# Afficher le résultat
print(median_events)
# Out:
#   event_group acc_type  median_value
# 0          PR      Bot           2.5
# 1      commit      Bot           3.5
# 2       issue      Bot          57.0
# 3  repository      Bot           3.5
# 4          PR    Human          13.0
# 5      commit    Human           1.5
# 6       issue    Human          22.0
# 7  repository    Human           1.0

# %% [markdown]
# ### Question 2 (b)
#
# Plot a heatmap of the DataFrame using seaborn -
# 1. First convert the dataframe to the required format using pivot, example is given below
# 2. plot using seaborn - sns.heatmap(df_medians, annot=True, vmin=0, vmax=300, cmap="crest"). More details: https://seaborn.pydata.org/generated/seaborn.heatmap.html)

# %% [markdown]
# #### pd.pivot example:
# <a id='pivot_example'></a>

# %%
# Main DataFrame
medians = [{'event_group': 'event_group1', 'median': 'val1', 'acc_type': 'Bot'}, 
           {'event_group': 'event_group1', 'median': 'val2', 'acc_type': 'Human'},
           {'event_group': 'event_group2', 'median': 'val3', 'acc_type': 'Bot'},
           {'event_group': 'event_group2', 'median': 'val4', 'acc_type': 'Human'},
           {'event_group': 'event_group3', 'median': 'val5', 'acc_type': 'Bot'},
           {'event_group': 'event_group3', 'median': 'val6', 'acc_type': 'Human'},
           {'event_group': 'event_group4', 'median': 'val7', 'acc_type': 'Bot'},
           {'event_group': 'event_group5', 'median': 'val8', 'acc_type': 'Human'}]
df_medians = pd.DataFrame.from_dict(medians)
df_medians
# Out:
#     event_group median acc_type
# 0  event_group1   val1      Bot
# 1  event_group1   val2    Human
# 2  event_group2   val3      Bot
# 3  event_group2   val4    Human
# 4  event_group3   val5      Bot
# 5  event_group3   val6    Human
# 6  event_group4   val7      Bot
# 7  event_group5   val8    Human

# %%
# pivot the main DataFrame
df_medians.pivot(index='acc_type', columns='event_group', values='median')#.reset_index().rename_axis(None,axis=1)
# Out:
# event_group event_group1 event_group2 event_group3 event_group4 event_group5
# acc_type
# Bot                 val1         val3         val5         val7          NaN
# Human               val2         val4         val6          NaN         val8

# %%
# YOUR CODE BELOW

# %%
# YOUR CODE BELOW

# %% [markdown]
# #### What is the difference that you observe between Bots+Bot actors and Humans?

# %% [markdown]
# #### What is the differnce that you observe between Event groups?

# %% [markdown]
# #### What is the difference that you observe between Bots+Bot actors and Humans and Event groups all considering at the same time?

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### Create boxen plots to visualise the distribution of number of events in each event group.
# #### For more information you can visit - https://seaborn.pydata.org/generated/seaborn.boxenplot.html#seaborn.boxenplot
# #### You should highlight the data points that correspond to bots using a stripplot in seaborn. https://seaborn.pydata.org/tutorial/categorical.html#categorical-tutorial
# #### Interpret the results of the visualisation.

# %%
# YOUR CODE BELOW - Visualize number of events from pull request event group

# %%
# YOUR CODE BELOW - Visualise number of events from issue event group

# %%
# YOUR CODE BELOW - Visualise number of events from commit event group

# %%
# YOUR CODE BELOW - Visualise number of events from repo event group

# %% [markdown]
# ### Question 4.1

# %% [markdown]
# #### Statistical identify whether number of events in each event group is normally distributed or not.
# #### Null hypothesis - $H_0$: Sample comes from the data that has normal distribution.
# #### Use Shapiro-Wilk test for this purpose. Use the p-value with a threshold of 0.05 to determine whether $H_0$ can be rejected with statistical significance or not.
#
# #### Use shapiro from scipy.stats to perform this test (https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html)

# %%
# YOUR CODE BELOW

# %% [markdown]
# ### Question 4.2
# #### Determine if there is any statistical diﬀerence in number of events between the identified event groups. Perform this test on all pairs of event groups.
# #### Null hypothesis - $H_0$: Any two event group come from the same population.
# #### If $H_0$ is rejected in Shapiro-Wilk test (at least for one of the two event groups considered for test), use the Mann-Whitney U statistical test for this purpose. If $H_0$ is not rejected in Shapiro-Wilk test, use the independent t-test for this purpose.
# #### In any case, use the p-value with a threshold of 0.01 to determine whether $H_0$ can be rejected with statistical significance.
#
# #### Use mannwhitneyu from scipy.stats to perform Mann-Whitney U test (https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html)
# #### or
# #### ttest_ind from scipy.stats to perform independent t-test https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html.

# %% [markdown]
# #### More information:
#
# You can pass the following arguments to mannwhitneyu from scipy.stats - (method='exact', nan_policy='omit'). For ttest_ind you can use - (nan_policy='omit')

# %%
# YOUR CODE BELOW

# %% [markdown]
# ### Question 4.3
# #### Each time you reject the null hypothesis $H_0$, quantify the effect size of the diﬀerence between the groups using cliﬀ’s delta ($\delta$).
# #### To calculate cliﬀ’s delta, you can pass the list of values to cliﬀ delta.py file given in the repository. E.g., cliffsDelta.cliffsDelta(list of values, list of values). This will return the effect size.
# #### Refer to the table given in the TP document and mention your interpretation (negligible, small, medium, large).

# %%
# YOU CODE BELOW
